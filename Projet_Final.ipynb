# %% [markdown]
# ## Libraries Import

# %%
import time
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
import pandas as pd
from pathlib import Path
import streamlit as st
from bs4 import *
import requests 
import os

# %% [markdown]
# ## Scrap Img BeautifulSoup

# %% [markdown]
# ###  Scrap API

# %%
# importing required libraries
import requests
from bs4 import BeautifulSoup

# target URL
url = "https://royaleapi.com/cards/popular?time=7d&mode=grid&cat=TopLadder&sort=rating"

headers = {
    'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
    }

response = requests.request("GET", url, headers=headers)

data = BeautifulSoup(response.text, 'html.parser')

# find all with the image tag
images = data.find_all('img', src=True)

# select src tag
image_src = [x['src'] for x in images]

# select format images
image_src = [x for x in image_src if x.startswith('https://cdn.royaleapi.com/static/img/cards-150/')]

print('Number of Images: ', len(image_src))

image_count = 1
for image in image_src:
    with open('img2/image_'+str(image_count)+'.jpg', 'wb') as f:
        res = requests.get(image)
        f.write(res.content)
    image_count = image_count+1
if image_count == len(image_src): 
        print("All Images Downloaded!") 
else: 
    print(f"Total {image_count-1} Images Downloaded Out of {len(image_src)}")
# Out:
# Number of Images:  106
# Total 106 Images Downloaded Out of 106

# %% [markdown]
# ### Scrap WebSite

# %%
def folder_create(images): 
    try: 
        folder_name = 'img' 
        
        os.mkdir(folder_name)
    except: 
        print("Folder Exist with that name!") 
        folder_create() 
    download_images(images, folder_name) 
  
  
def download_images(images, folder_name): 
    count = 0
    print(f"Total {len(images)} Image Found!") 
    if len(images) != 0: 
        for i, image in enumerate(images): 
            try: 
                image_link = image["data-srcset"] 
            except: 
                try: 
                    image_link = image["data-src"] 
                except: 
                    try: 
                        image_link = image["data-fallback-src"] 
                    except: 
                        try: 
                            image_link = image["src"]   
                        except: 
                            pass
            try: 
                r = requests.get(image_link).content 
                try: 
                    r = str(r, 'utf-8') 
                except UnicodeDecodeError: 
                    with open(f"{folder_name}/images{i+1}.jpg", "wb+") as f: 
                        f.write(r) 
                    count += 1
            except: 
                pass
        if count == len(images): 
            print("All Images Downloaded!") 
        else: 
            print(f"Total {count} Images Downloaded Out of {len(images)}") 
  
def main(url): 
    
    r = requests.get(url) 
    soup = BeautifulSoup(r.text, 'html.parser') 
    images = soup.findAll('img') 
    folder_create(images) 
 
# url = input("Enter URL:- ") 

url = 'https://statsroyale.com/fr/top/cards'

main(url)
# Out:
# Total 110 Image Found!
# All Images Downloaded!

# %% [markdown]
# ## Scraping Data Selenium

# %%
browser = webdriver.Chrome('/Users/guill/Desktop/Ynov B3/Python/ChromeDriver/chromedriver')
browser2 = webdriver.Chrome('/Users/guill/Desktop/Ynov B3/Python/ChromeDriver/chromedriver')
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_3584\2348363629.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('/Users/guill/Desktop/Ynov B3/Python/ChromeDriver/chromedriver')
# C:\Users\guill\AppData\Local\Temp\ipykernel_3584\2348363629.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser2 = webdriver.Chrome('/Users/guill/Desktop/Ynov B3/Python/ChromeDriver/chromedriver')

# %%
browser.get('https://royaleapi.com/cards/popular?time=7d&cat=TopLadder&sort=rating&mode=table')
browser2.get('https://royaleapi.com/cards/popular?time=7d&cat=TopLadder&sort=rating&mode=grid')
time.sleep(3)

# %%
browser.maximize_window()
browser2.maximize_window()
time.sleep(2)

# %%
ListModeleDF = []
ListModeleCards = []
for articles in range(1,107):
    rank = browser2.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/div[2]/div["+str(articles)+"]/div[1]")
    notation = browser.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/table/tbody/tr["+str(articles)+"]/td[3]")
    utilisation = browser.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/table/tbody/tr["+str(articles)+"]/td[4]")
    win = browser.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/table/tbody/tr["+str(articles)+"]/td[6]")
    name = browser.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/table/tbody/tr["+str(articles)+"]/td[2]")
    
    ListModeleCards.append(str(name.text))
    ListModeleCards.append(str(rank.text))
    ListModeleCards.append(str(notation.text))
    ListModeleCards.append(str(utilisation.text))
    ListModeleCards.append(str(win.text))
    ListModeleDF.append(ListModeleCards[:])
    ListModeleCards.clear()
    print(rank.text,notation.text,utilisation.text,win.text,name.text)

browser.close()
browser2.close()
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_3584\645618426.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rank = browser2.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/div[2]/div["+str(articles)+"]/div[1]")
# C:\Users\guill\AppData\Local\Temp\ipykernel_3584\645618426.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   notation = browser.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/table/tbody/tr["+str(articles)+"]/td[3]")
# C:\Users\guill\AppData\Local\Temp\ipykernel_3584\645618426.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   utilisation = browser.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/table/tbody/tr["+str(articles)+"]/td[4]")
# C:\Users\guill\AppData\Local\Temp\ipykernel_3584\645618426.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   win = browser.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/table/tbody/tr["+str(articles)+"]/td[6]")
# C:\Users\guill\AppData\Local\Temp\ipykernel_3584\645618426.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = browser.find_element_by_xpath("/html/body/div[3]/div[4]/div[2]/div[3]/div[3]/table/tbody/tr["+str(articles)+"]/td[2]")
# 1 52 6% 51% Skeleton King
# 2 51 25% 51% Archer Queen
# 3 51 13% 51% Giant Snowball
# 4 51 8% 51% Royal Hogs
# 5 51 12% 51% Royal Ghost
# 6 50 18% 50% Bandit
# 7 50 5% 51% Ice Wizard
# 8 50 20% 50% Tornado
# 9 50 18% 50% Barbarian Barrel
# 10 50 12% 50% Fire Spirit
# 11 50 14% 50% Graveyard
# 12 50 10% 50% Rocket
# 13 50 7% 51% Royal Delivery
# 14 49 9% 50% Cannon
# 15 49 12% 50% Lightning
# 16 49 6% 51% Bowler
# 17 49 4% 51% Electro Giant
# 18 49 13% 50% Electro Spirit
# 19 49 4% 51% Spear Goblins
# 20 49 5% 50% Bomber
# 21 49 5% 50% Freeze
# 22 49 6% 50% Fisherman
# 23 49 16% 50% Bats
# 24 49 2% 51% Mother Witch
# 25 49 34% 50% The Log
# 26 49 16% 50% Skeleton Army
# 27 49 19% 50% Valkyrie
# 28 49 5% 50% Royal Giant
# 29 48 16% 50% Dark Prince
# 30 48 10% 50% Earthquake
# 31 48 6% 50% P.E.K.K.A
# 32 48 3% 50% Zappies
# 33 48 7% 50% Princess
# 34 48 12% 50% Baby Dragon
# 35 48 4% 50% X-Bow
# 36 48 10% 50% Mega Knight
# 37 48 9% 50% Tombstone
# 38 48 4% 50% Cannon Cart
# 39 48 22% 50% Skeletons
# 40 48 6% 50% Heal Spirit
# 41 48 6% 50% Inferno Tower
# 42 48 5% 50% Battle Ram
# 43 47 6% 50% Ram Rider
# 44 47 20% 49% Arrows
# 45 47 7% 50% Goblin Barrel
# 46 47 13% 50% Giant
# 47 47 5% 50% Hunter
# 48 47 2% 50% Rascals
# 49 47 4% 50% Barbarians
# 50 47 4% 50% Goblin Cage
# 51 47 28% 49% Fireball
# 52 46 10% 49% Guards
# 53 46 5% 49% Minions
# 54 46 21% 49% Zap
# 55 46 12% 49% Electro Wizard
# 56 46 6% 49% Night Witch
# 57 46 3% 50% Goblin Drill
# 58 46 7% 49% Magic Archer
# 59 46 7% 49% Lumberjack
# 60 46 3% 50% Witch
# 61 46 3% 49% Electro Dragon
# 62 46 8% 49% Balloon
# 63 46 5% 49% Wall Breakers
# 64 46 6% 49% Minion Horde
# 65 46 7% 49% Ice Golem
# 66 46 6% 49% Sparky
# 67 45 4% 49% Dart Goblin
# 68 45 5% 49% Mortar
# 69 45 15% 49% Miner
# 70 45 6% 49% Mini P.E.K.K.A
# 71 45 11% 49% Inferno Dragon
# 72 45 3% 50% Three Musketeers
# 73 45 7% 49% Elite Barbarians
# 74 45 7% 49% Tesla
# 75 45 12% 49% Mega Minion
# 76 45 9% 49% Hog Rider
# 77 45 2% 50% Executioner
# 78 45 2% 50% Skeleton Barrel
# 79 45 3% 49% Goblin Gang
# 80 44 5% 49% Golem
# 81 44 6% 49% Poison
# 82 44 1% 50% Goblins
# 83 44 7% 48% Lava Hound
# 84 43 1% 50% Wizard
# 85 43 7% 48% Musketeer
# 86 43 4% 48% Skeleton Dragons
# 87 43 4% 48% Flying Machine
# 88 43 0% 51% Furnace
# 89 43 4% 48% Prince
# 90 42 5% 48% Knight
# 91 42 4% 48% Ice Spirit
# 92 42 2% 49% Elixir Collector
# 93 42 3% 48% Bomb Tower
# 94 42 2% 48% Clone
# 95 41 0% 50% Barbarian Hut
# 96 41 1% 48% Royal Recruits
# 97 40 2% 48% Archers
# 98 40 1% 49% Mirror
# 99 39 1% 48% Elixir Golem
# 100 39 2% 47% Goblin Giant
# 101 39 1% 48% Battle Healer
# 102 38 3% 47% Rage
# 103 38 1% 48% Giant Skeleton
# 104 37 1% 49% Goblin Hut
# 105 36 1% 47% Golden Knight
# 106 35 1% 46% Firecracker

# %% [markdown]
# ## Pandas DataFrame

# %%
df = pd.DataFrame(ListModeleDF)    
df.columns += 1 
df.to_csv("clash_stats.csv")

# %%
df = pd.read_csv("clash_stats.csv", encoding='utf-8')
df = df.rename(columns={'1': 'Nom', '2': 'Rang', '3': 'Notation /100', '4': 'Utilisation %', '5': 'Victoire %'})
df.set_index('Nom', inplace = True)

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
df["Utilisation %"] = df["Utilisation %"].replace('\%','',regex=True).astype(int)
df["Victoire %"] = df["Victoire %"].replace('\%','',regex=True).astype(int)

# %%
df
# Out:
#                 Rang  Notation /100  Utilisation %  Victoire %
# Nom
# Skeleton King      1             52              6          51
# Archer Queen       2             51             25          51
# Giant Snowball     3             51             13          51
# Royal Hogs         4             51              8          51
# Royal Ghost        5             51             12          51
# ...              ...            ...            ...         ...
# Rage             102             38              3          47
# Giant Skeleton   103             38              1          48
# Goblin Hut       104             37              1          49
# Golden Knight    105             36              1          47
# Firecracker      106             35              1          46
#
# [106 rows x 4 columns]

# %%
df.sort_values(by=['Utilisation %'], ascending=False)
# Out:
#                 Rang  Notation /100  Utilisation %  Victoire %
# Nom
# The Log           25             49             34          50
# Fireball          51             47             28          49
# Archer Queen       2             51             25          51
# Skeletons         39             48             22          50
# Zap               54             46             21          49
# ...              ...            ...            ...         ...
# Royal Recruits    96             41              1          48
# Wizard            84             43              1          50
# Firecracker      106             35              1          46
# Barbarian Hut     95             41              0          50
# Furnace           88             43              0          51
#
# [106 rows x 4 columns]

# %%
# Importing the necessary libraries
from IPython.core.display import HTML

# %%
# target URL
url = "https://royaleapi.com/cards/popular?time=7d&mode=grid&cat=TopLadder&sort=rating"

headers = {
    'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
    }

response = requests.request("GET", url, headers=headers)

data = BeautifulSoup(response.text, 'html.parser')

# find all with the image tag
images = data.find_all('img', src=True)

# select src tag
image_src = [x['src'] for x in images]

# select format images
image_src = [x for x in image_src if x.startswith('https://cdn.royaleapi.com/static/img/cards-150/')]

image = image_src

# %%
df['Image'] = image

# %%
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

# %%
# Rendering the dataframe as HTML table
df.to_html(escape=False, formatters=dict(Image=path_to_image_html))
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Rang</th>\n      <th>Notation /100</th>\n      <th>Utilisation %</th>\n      <th>Victoire %</th>\n      <th>Image</th>\n    </tr>\n    <tr>\n      <th>Nom</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Skeleton King</th>\n      <td>1</td>\n      <td>52</td>\n      <td>6</td>\n      <td>51</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/skeleton-king.png?t=478f6d6fc" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Archer Queen</th>\n      <td>2</td>\n      <td>51</td>\n      <td>25</td>\n      <td>51</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/archer-queen.png?t=e4e7786bc" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Giant Snowball</th>\n      <td>3</td>\n      <td>51</td>\n      <td>13</td>\n      <td>51</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/giant-snowball.png?t=6d89c329c" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Royal Hogs</th>\n      <td>4</td>\n      <td>51</td>\n      <td>8</td>\n      <td>51</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/royal-hogs.png?t=73882ad4c" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Royal Ghost</th>\n      <td>5</td>\n      <td>51</td>\n      <td>12</td>\n      <td>51</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/royal-ghost.png?t=e27318bac" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Bandit</th>\n      <td>6</td>\n      <td>50</td>\n      <td>18</td>\n      <td>50</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/bandit.png?t=54db18bfc" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Ice Wizard</th>\n      <td>7</td>\n      <td>50</td>\n      <td>5</td>\n      <td>51</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/ice-wizard.png?t=a17a82fec" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Tornado</th>\n      <td>8</td>\n      <td>50</td>\n      <td>20</td>\n      <td>50</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/tornado.png?t=a7cb4080c" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Barbarian Barrel</th>\n      <td>9</td>\n      <td>50</td>\n      <td>18</td>\n      <td>50</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/barbarian-barrel.png?t=e1f67d00c" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Fire Spirit</th>\n      <td>10</td>\n      <td>50</td>\n      <td>12</td>\n      <td>50</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/fire-spirit.png?t=ebb76b7bc" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Graveyard</th>\n      <td>11</td>\n      <td>50</td>\n      <td>14</td>\n      <td>50</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/graveyard.png?t=9d9212c9c" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Rocket</th>\n      <td>12</td>\n      <td>50</td>\n      <td>10</td>\n      <td>50</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/rocket.png?t=5b9cdb19c" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Royal Delivery</th>\n      <td>13</td>\n      <td>50</td>\n      <td>7</td>\n      <td>51</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/royal-delivery.png?t=112ed855c" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Cannon</th>\n      <td>14</td>\n      <td>49</td>\n      <td>9</td>\n      <td>50</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/cannon.png?t=59642b37c" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Lightning</th>\n      <td>15</td>\n      <td>49</td>\n      <td>12</td>\n      <td>50</td>\n      <td><img src="https://cdn.royaleapi.com/static/img/cards-150/lightning.png?t=737a5d4fc" width="60" ></td>\n    </tr>\n    <tr>\n      <th>Bowler</th>\n      <td ...

# %%
# Rendering the images in the dataframe using the HTML method.
HTML(df.to_html(escape=False,formatters=dict(Image=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rang</th>
#       <th>Notation /100</th>
#       <th>Utilisation %</th>
#       <th>Victoire %</th>
#       <th>Image</th>
#     </tr>
#     <tr>
#       <th>Nom</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Skeleton King</th>
#       <td>1</td>
#       <td>52</td>
#       <td>6</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/skeleton-king.png?t=478f6d6fc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Archer Queen</th>
#       <td>2</td>
#       <td>51</td>
#       <td>25</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/archer-queen.png?t=e4e7786bc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Giant Snowball</th>
#       <td>3</td>
#       <td>51</td>
#       <td>13</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/giant-snowball.png?t=6d89c329c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Royal Hogs</th>
#       <td>4</td>
#       <td>51</td>
#       <td>8</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/royal-hogs.png?t=73882ad4c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Royal Ghost</th>
#       <td>5</td>
#       <td>51</td>
#       <td>12</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/royal-ghost.png?t=e27318bac" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Bandit</th>
#       <td>6</td>
#       <td>50</td>
#       <td>18</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/bandit.png?t=54db18bfc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Ice Wizard</th>
#       <td>7</td>
#       <td>50</td>
#       <td>5</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/ice-wizard.png?t=a17a82fec" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Tornado</th>
#       <td>8</td>
#       <td>50</td>
#       <td>20</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/tornado.png?t=a7cb4080c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Barbarian Barrel</th>
#       <td>9</td>
#       <td>50</td>
#       <td>18</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/barbarian-barrel.png?t=e1f67d00c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Fire Spirit</th>
#       <td>10</td>
#       <td>50</td>
#       <td>12</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/fire-spirit.png?t=ebb76b7bc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Graveyard</th>
#       <td>11</td>
#       <td>50</td>
#       <td>14</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/graveyard.png?t=9d9212c9c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Rocket</th>
#       <td>12</td>
#       <td>50</td>
#       <td>10</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/rocket.png?t=5b9cdb19c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Royal Delivery</th>
#       <td>13</td>
#       <td>50</td>
#       <td>7</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/royal-delivery.png?t=112ed855c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Cannon</th>
#       <td>14</td>
#       <td>49</td>
#       <td>9</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/cannon.png?t=59642b37c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Lightning</th>
#       <td>15</td>
#       <td>49</td>
#       <td>12</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/lightning.png?t=737a5d4fc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Bowler</th>
#       <td>16</td>
#       <td>49</td>
#       <td>6</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/bowler.png?t=e002e425c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Electro Giant</th>
#       <td>17</td>
#       <td>49</td>
#       <td>4</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/electro-giant.png?t=62ecf407c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Electro Spirit</th>
#       <td>18</td>
#       <td>49</td>
#       <td>13</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/electro-spirit.png?t=c949f811c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Spear Goblins</th>
#       <td>19</td>
#       <td>49</td>
#       <td>4</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/spear-goblins.png?t=1d2c07f3c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Bomber</th>
#       <td>20</td>
#       <td>49</td>
#       <td>5</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/bomber.png?t=10d58c91c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Freeze</th>
#       <td>21</td>
#       <td>49</td>
#       <td>5</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/freeze.png?t=7f17666cc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Fisherman</th>
#       <td>22</td>
#       <td>49</td>
#       <td>6</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/fisherman.png?t=935a09edc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Bats</th>
#       <td>23</td>
#       <td>49</td>
#       <td>16</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/bats.png?t=a933961bc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Mother Witch</th>
#       <td>24</td>
#       <td>49</td>
#       <td>2</td>
#       <td>51</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/mother-witch.png?t=6d741047c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>The Log</th>
#       <td>25</td>
#       <td>49</td>
#       <td>34</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/the-log.png?t=657441f0c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Skeleton Army</th>
#       <td>26</td>
#       <td>49</td>
#       <td>16</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/skeleton-army.png?t=25c76efec" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Valkyrie</th>
#       <td>27</td>
#       <td>49</td>
#       <td>19</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/valkyrie.png?t=f61dfb98c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Royal Giant</th>
#       <td>28</td>
#       <td>49</td>
#       <td>5</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/royal-giant.png?t=92555378c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Dark Prince</th>
#       <td>29</td>
#       <td>48</td>
#       <td>16</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/dark-prince.png?t=bc9d6089c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Earthquake</th>
#       <td>30</td>
#       <td>48</td>
#       <td>10</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/earthquake.png?t=f5b9340dc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>P.E.K.K.A</th>
#       <td>31</td>
#       <td>48</td>
#       <td>6</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/pekka.png?t=9b8115dfc" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Zappies</th>
#       <td>32</td>
#       <td>48</td>
#       <td>3</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/zappies.png?t=47acee13c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Princess</th>
#       <td>33</td>
#       <td>48</td>
#       <td>7</td>
#       <td>50</td>
#       <td><img src="https://cdn.royaleapi.com/static/img/cards-150/princess.png?t=9d70d258c" width="60" ></td>
#     </tr>
#     <tr>
#       <th>Baby Dragon</th>
#       <td>34</td>
#       <td>48</td>
#       <td>12
